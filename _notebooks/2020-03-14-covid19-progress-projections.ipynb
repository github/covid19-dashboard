# %% [markdown]
# # Projections of ICU need by Country
# > Modeling current and future ICU demand.
#
# - categories: [overview]
# - author: <a href=https://github.com/artdgn/>artdgn</a>
# - image: images/covid-progress-projections.png
# - permalink: /covid-progress-projections/
# - toc: false
# - hide: false

# %% [markdown]
# > Warning: This dashboard was not prepared by an Epidemiologist and contains speculative information.  This data should not be used for public health or policy making without fully understanding the assumptions and methodology presented.

# %%
#hide
import pandas as pd
import overview_helpers

helper = overview_helpers.OverviewDataExtras
df = helper.filter_df(helper.table_with_projections())
df.columns
# Out:
# Index(['Cases.new', 'Cases.new.est', 'Cases.new.per100k',
#        'Cases.new.per100k.est', 'Cases.total', 'Cases.total.est',
#        'Cases.total.per100k', 'Cases.total.per100k.est', 'Continent',
#        'Deaths.new', 'Deaths.new.per100k', 'Deaths.total',
#        'Deaths.total.per100k', 'Fatality Rate', 'affected_ratio',
#        'affected_ratio.est', 'affected_ratio.est.+14d',
#        'affected_ratio.est.+30d', 'affected_ratio.est.+60d',
#        'affected_ratio.est.+7d', 'affected_ratio.est.+90d', 'growth_rate',
#        'icu_capacity_per100k', 'icu_spare_capacity_per100k', 'needICU.per100k',
#        'needICU.per100k.+14d', 'needICU.per100k.+30d', 'needICU.per100k.+60d',
#        'needICU.per100k.+7d', 'needICU.per100k.+90d', 'peak_icu_neek_per100k',
#        'population', 'testing_bias'],
#       dtype='object')

# %% [markdown]
# ## Estimated need for ICU beds
#
# > Countries sorted by current ICU demand
#
# - ICU need is estimated as [6% of active cases](https://medium.com/@joschabach/flattening-the-curve-is-a-deadly-delusion-eea324fe9727).
# - ICU capacities are from [Wikipedia](https://en.wikipedia.org/wiki/List_of_countries_by_hospital_beds) (OECD countries mostly) and [CCB capacities in Asia](https://www.researchgate.net/publication/338520008_Critical_Care_Bed_Capacity_in_Asian_Countries_and_Regions).
# - ICU spare capacity is based on 70% normal occupancy rate ([66% in US](https://www.sccm.org/Blog/March-2020/United-States-Resource-Availability-for-COVID-19), [75% OECD](https://www.oecd-ilibrary.org/social-issues-migration-health/health-at-a-glance-2019_4dd50c09-en))
# - Details of estimation and prediction calculations are in [Appendix](#appendix).
# - Column definitions:
#     - <font size=2><b>Estimated ICU need per 100k population</b>: number of ICU beds estimated to be needed per 100k population by COVID-19 patents.</font>
#     - <font size=2><b>Projected in 14 days</b>: projected ICU need per 100k population in 14 days.</font>
#     - <font size=2><b>Projected in 30 days</b>: projected ICU need per 100k population in 30 days.</font>
#     - <font size=2><b>ICU capacity per 100k</b>: number of ICU beds per 100k population.</font>
#     - <font size=2><b>Estimated ICU Spare capacity per 100k</b>: estimated ICU capacity per 100k population based on assumed normal occupancy rate of 70% and number of ICU beds (only for countries with ICU beds data).</font>
#     - <font size=2><b>Estimated daily case growth rate</b>: percentage daily change in total cases during last 5 days.</font>

# %%
#hide_input
rename_cols = {'needICU.per100k': 'Estimated <br> ICU need <br> per 100k <br> population',
               'needICU.per100k.+14d': 'Projected <br> In 14 days', 
               'needICU.per100k.+30d': 'Projected <br> In 30 days',               
               'icu_capacity_per100k': 'ICU <br> capacity <br> per 100k',
               'icu_spare_capacity_per100k': 'Estimated ICU <br> Spare capacity <br> per 100k',               
               'growth_rate': 'Estimated <br> daily case <br> growth rate',
              }
icu_cols = list(rename_cols.values())[:3]
df_icu_bars = df.rename(rename_cols, axis=1)
df_icu_bars.sort_values(rename_cols['needICU.per100k'], ascending=False)\
[rename_cols.values()].style\
    .bar(subset=icu_cols[0], color='#b21e3e', vmin=0, vmax=10)\
    .bar(subset=icu_cols[1], color='#f43d64', vmin=0, vmax=10)\
    .bar(subset=icu_cols[2], color='#ef8ba0', vmin=0, vmax=10)\
    .bar(subset=[rename_cols['icu_spare_capacity_per100k']], color='#3ab1d8', vmin=0, vmax=10)\
    .applymap(lambda _: 'color: blue', subset=[rename_cols['icu_spare_capacity_per100k']])\
    .bar(subset=[rename_cols['growth_rate']], color='#d65f5f', vmin=0, vmax=0.33)\
    .format('<b>{:.1%}</b>', subset=[rename_cols['growth_rate']])\
    .format('<b>{:.1f}</b>', subset=[rename_cols['icu_capacity_per100k']], na_rep="-")\
    .format('<b>{:.1f}</b>', subset=[rename_cols['icu_spare_capacity_per100k']], na_rep="-")\
    .format('<b>{:.2f}</b>', subset=icu_cols)\
    .set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 10.9%, transparent 10.9%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 41.0%, transparent 41.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 100.0%, transparent 100.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 100.0%, transparent 100.0%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 8.0%, transparent 8.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 13.3%, transparent 13.3%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 22.6%, transparent 22.6%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 29.1%, transparent 29.1%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.5%, transparent 19.5%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 7.8%, transparent 7.8%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 36.7%, transparent 36.7%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 100.0%, transparent 100.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 34.8%, transparent 34.8%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.0%, transparent 43.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 6.4%, transparent 6.4%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 9.1%, transparent 9.1%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 13.5%, transparent 13.5%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 37.5%, transparent 37.5%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 12.2%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 5.7%, transparent 5.7%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 24.6%, transparent 24.6%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 100.0%, transparent 100.0%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 19.8%, transparent 19.8%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.9%, transparent 40.9%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 1.8%, transparent 1.8%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 2.7%, transparent 2.7%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 4.6%, transparent 4.6%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 13.8%, transparent 13.8%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.4%, transparent 16.4%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 1.2%, transparent 1.2%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 2.7%, transparent 2.7%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 6.6%, transparent 6.6%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row6_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 47.7%, transparent 47.7%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row6_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.2%, transparent 27.2%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b21e3e 1.1%, transparent 1.1%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row7_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f43d64 2.2%, transparent 2.2%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ef8ba0 4.6%, transparent 4.6%);
#         }    #T_5a04af88_77d3_11ea_81d8_000d3a1f0204row7_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3ab1d8 19.2%, transparent 19.2%);
#             color:  blue;
#         }    #T_5a04af88_77d3_11ea

# %% [markdown]
# # Appendix
#
# ## Projected Affected Population percentage
#
# > Countries sorted by number of new cases in last 5 days.  The projected affected population percentage is directly related to the calculation of estimated ICU need.

# %% [markdown]
# - Column definitions:
#     - <font size=2><b>Estimated <i>new</i> cases in last 5 days</b>: estimated new cases in last 5 days.</font>
#     - <font size=2><b>Estimated <i>total</i> affected population percentage</b>: estimated percentage of total population already affected (infected, recovered, or dead).</font>
#     - <font size=2><b>Projected in 14 days</b>: projected percentage of total affected population in 14 days.</font>
#     - <font size=2><b>Projected in 30 days</b>: projected percentage of total affected population in 30 days.</font>
#     - <font size=2><b>Reported fatality percentage</b>: reported total deaths divided by total cases.</font>
#     - <font size=2><b>Estimated daily case growth rate</b>: percentage daily change in total cases during last 5 days</font>.

# %%
#hide_input
rename_cols = {'Cases.new.est': 'Estimated <br> <i>new</i> cases <br> in last 5 days', 
               'affected_ratio.est': 'Estimated <br> <i>total</i> affected <br> population <br> percentage',
               'affected_ratio.est.+14d': 'Projected <br> In 14 days',
               'affected_ratio.est.+30d': 'Projected <br> In 30 days',
               'Fatality Rate': 'Reported <br> fatality <br> percentage',
               'growth_rate': 'Estimated <br> daily case <br> growth rate',
              }
progress_cols = list(rename_cols.values())[:4]
df_progress_bars = df.rename(rename_cols, axis=1)
df_progress_bars.sort_values(rename_cols['Cases.new.est'], ascending=False)\
[rename_cols.values()].style\
    .bar(subset=progress_cols[0], color='#b57b17')\
    .bar(subset=progress_cols[1], color='#5dad64', vmin=0, vmax=1.0)\
    .bar(subset=progress_cols[2], color='#719974', vmin=0, vmax=1.0)\
    .bar(subset=progress_cols[3], color='#a1afa3', vmin=0, vmax=1.0)\
    .bar(subset=[rename_cols['Fatality Rate']], color='#420412', vmin=0, vmax=0.1)\
    .applymap(lambda _: 'color: red', subset=[rename_cols['Fatality Rate']])\
    .bar(subset=[rename_cols['growth_rate']], color='#d65f5f', vmin=0, vmax=0.33)\
    .format('<b>{:,.0f}</b>', subset=list(rename_cols.values())[0])\
    .format('<b>{:.1%}</b>', subset=list(rename_cols.values())[1:])
# Out:
# <style  type="text/css" >
#     #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 100.0%, transparent 100.0%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 0.5%, transparent 0.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 2.3%, transparent 2.3%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 11.2%, transparent 11.2%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 29.0%, transparent 29.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row0_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.8%, transparent 36.8%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 73.8%, transparent 73.8%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 2.0%, transparent 2.0%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 10.1%, transparent 10.1%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 45.6%, transparent 45.6%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 86.0%, transparent 86.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row1_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 43.0%, transparent 43.0%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 55.6%, transparent 55.6%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 1.4%, transparent 1.4%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 6.5%, transparent 6.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 31.5%, transparent 31.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 100.0%, transparent 100.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row2_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.9%, transparent 40.9%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 52.3%, transparent 52.3%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 3.2%, transparent 3.2%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 7.3%, transparent 7.3%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 15.4%, transparent 15.4%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 96.0%, transparent 96.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row3_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.5%, transparent 19.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 33.7%, transparent 33.7%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 2.4%, transparent 2.4%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 4.5%, transparent 4.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 8.1%, transparent 8.1%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 100.0%, transparent 100.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row4_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 12.2%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 11.7%, transparent 11.7%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 0.5%, transparent 0.5%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 0.9%, transparent 0.9%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#a1afa3 1.8%, transparent 1.8%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#420412 62.0%, transparent 62.0%);
#             color:  red;
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row5_col5 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.4%, transparent 16.4%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#b57b17 9.3%, transparent 9.3%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row6_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5dad64 1.8%, transparent 1.8%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#719974 5.2%, transparent 5.2%);
#         }    #T_5a04af89_77d3_11ea_81d8_000d3a1f0204row6_col3 {
#             width:  10em;

# %% [markdown]
# <a id='appendix'></a>
# ## Methodology & Assumptions
#
# - Total case estimation calculated from deaths by:
#     - Assuming that unbiased fatality rate is 1.5% (from heavily tested countries / the cruise ship data) and that it takes 8 days on average for a case to go from being confirmed positive (after incubation + testing lag) to death. This is the same figure used by ["Estimating The Infected Population From Deaths"](https://covid19dashboards.com/covid-infected/) in this repo.
#     - Testing bias: the actual lagged fatality rate is than divided by the 1.5% figure to estimate the testing bias in a country. The estimated testing bias then multiplies the reported case numbers to estimate the *true* case numbers (*=case numbers if testing coverage was as comprehensive as in the heavily tested countries*).
#     - The testing bias calculation is a high source of uncertainty in all these estimations and projections. Better source of testing bias (or just *true case* numbers), should make everything more accurate.
# - Projection is done using a simple [SIR model](https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology#The_SIR_model) with (see [examples](#examples)) combined with the approach in [Total Outstanding Cases](https://covid19dashboards.com/outstanding_cases/#Appendix:-Methodology-of-Predicting-Recovered-Cases):
#     - Growth rate calculated over the 5 past days. This is pessimistic - because it includes the testing rate growth rate as well, and is slow to react to both improvements in test coverage and "flattening" due to social isolation.
#     - Recovery probability being 1/20 (for 20 days to recover) where the rate estimated from [Total Outstanding Cases](https://covid19dashboards.com/outstanding_cases/#Appendix:-Methodology-of-Predicting-Recovered-Cases) is too high (on down-slopes).
# - ICU need is calculated as being [6% of active cases](https://medium.com/@joschabach/flattening-the-curve-is-a-deadly-delusion-eea324fe9727) where:
#     - Active cases are taken from the SIR model.
#     - This is both pessimistic - because real ICU rate may in reality be lower, due to testing biases, and especially in "younger" populations), and optimistic - because active cases which are on ICU take longer (so need the ICUs for longer).
#     - ICU capacities are from [Wikipedia](https://en.wikipedia.org/wiki/List_of_countries_by_hospital_beds) (OECD countries mostly) and [CCB capacities in Asia](https://www.researchgate.net/publication/338520008_Critical_Care_Bed_Capacity_in_Asian_Countries_and_Regions).
#     - ICU spare capacity is based on 70% normal occupancy rate ([66% in US](https://www.sccm.org/Blog/March-2020/United-States-Resource-Availability-for-COVID-19), [75% OECD](https://www.oecd-ilibrary.org/social-issues-migration-health/health-at-a-glance-2019_4dd50c09-en))

# %% [markdown]
# <a id='examples'></a>
#
# **Examples of modeling plots**
#
# For the 5 countries with highest estimated number of new cases.
# > Note: The purpose of the below plots is to demonstrate the actual calculations used in the tables above and the dynamics of the model.

# %%
#hide_input
sir_plot_countries = df.sort_values('Cases.new.est', ascending=False).head(5).index
helper.table_with_projections(plot_countries=sir_plot_countries);
